# %% [markdown]
# # Regressão Linear com NumPy

# %% [markdown]
# ## Objetivos deste experimento

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se programação totalmente NumPy com:
# - o **cálculo do gradiente**,
# - a **função de perda** e
# - a atualização dos parâmetros são feitos de forma explícita.
# - A rede é criada com uma camada como uma classe

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinear_Otimizacao.png)

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt   # para plotting

from sklearn.datasets import load_iris  # para carregar dataset

import numpy as np  # processamento matricial

np.random.seed(1234)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1]
y_train = data[:,1:2]

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float64
# y_train.shape: (50, 1) float64
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
plt.scatter(x_train,y_train)
plt.xlabel('Comprimento sepalas')
plt.ylabel('Comprimento petalas')
# Out:
# Text(0, 0.5, 'Comprimento petalas')

# %% [markdown]
# ## Modelo da rede

# %% [markdown]
# ### Reta de ajuste

# %% [markdown]
# A equação da reta no plano necessita de dois parâmetros, aqui denominados $w_0$ (*bias*) e inclinação $w_1$. Veja figura:
#
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/linhareta.png)
#
# A reta de ajuste será dada por:
#
# $$ \hat{y} = w_0 + w_1 x $$
#
# onde
# * $w_1$ é o coeficiente angular da reta e
# * $w_0$ é a interseção do eixo vertical quando x é igual a zero, também denominado de *bias*.
# * $x$ é a variável de entrada (comprimento das sépalas) e
# * $\hat{y}$ é a predição (comprimento estimado das pétalas).

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinearNeuronio.png)

# %% [markdown]
# ### Formulação matricial do neurônio

# %% [markdown]
# * $\mathbf{w} = [w_0 \ w_1]$ é vetor linha de parâmetros e
# * $\mathbf{x} = [1 \ x_0] $ é vetor linha de uma amostra (com *bias*).
#
# $$ \hat{y} = 1 w_0 + x_0 w_1 $$
#
# $$ [\hat{y}] = [1 \ x_0] \begin{bmatrix} w_0 \\ w_1 \end{bmatrix} $$
#
# $$ \mathbf{\hat{y}} = \mathbf{x} \mathbf{w^T} $$

# %% [markdown]
# ### Fazendo o predict de várias amostras

# %% [markdown]
# $$ \begin{matrix}
# \begin{bmatrix}
# \hat{y}_0\\
# \hat{y}_1\\
# \\
# \hat{y}_{M-1}
# \end{bmatrix} &=& \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1\\
# \\
# 1 & x_{M-1} \\
# \end{bmatrix}
# &
# \begin{bmatrix}
# w_0\\
# w_1
# \end{bmatrix} \\
# (M,1) & & (M,2) & (2,1) \\
# \end{matrix} $$

# %% [markdown]
# ### Preenchendo x com coluna de 1's para bias

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias
# Out:
# array([[1.        , 1.        ],
#        [1.        , 0.71428571],
#        [1.        , 0.95238095],
#        [1.        , 0.28571429],
#        [1.        , 0.76190476],
#        [1.        , 0.38095238],
#        [1.        , 0.66666667],
#        [1.        , 0.        ],
#        [1.        , 0.80952381],
#        [1.        , 0.14285714],
#        [1.        , 0.04761905],
#        [1.        , 0.47619048],
#        [1.        , 0.52380952],
#        [1.        , 0.57142857],
#        [1.        , 0.33333333],
#        [1.        , 0.85714286],
#        [1.        , 0.33333333],
#        [1.        , 0.42857143],
#        [1.        , 0.61904762],
#        [1.        , 0.33333333],
#        [1.        , 0.47619048],
#        [1.        , 0.57142857],
#        [1.        , 0.66666667],
#        [1.        , 0.57142857],
#        [1.        , 0.71428571],
#        [1.        , 0.80952381],
#        [1.        , 0.9047619 ],
#        [1.        , 0.85714286],
# ...

# %% [markdown]
# ### Classe com o modelo da rede

# %%
class Net():
    def __init__(self, n_in, n_out):
        self.w = np.random.uniform(-0.1,0.1,(n_out,n_in)) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.dot(self.w.T)

# %% [markdown]
# ### Criando a rede, instanciando o objeto model

# %%
model = Net(2,1) # duas entradas (1 + x0) e uma saída y_pred

# %% [markdown]
# ### Testando o predict da rede (mesmo sem treiná-la)

# %%
xin = np.random.randn(4,2) # 4 amostras, 2 entradas (1 + x0)
ypred = model.forward(xin)
ypred
# Out:
# array([[-0.09602795],
#        [ 0.0661236 ],
#        [-0.06857828],
#        [-0.05573871]])

# %% [markdown]
# ## Atividade 2

# %%
# ATIVIDADE 2
# MSE da rede com os parâmetros inicializados (sem treinamento)

y_pred_inicial = model.forward(x_train_bias)

mse_inicial = np.square(y_pred_inicial - y_train).mean()

print('MSE inicial:', mse_inicial)
# Out:
# MSE inicial: 0.46916299392848965

# %% [markdown]
# ## Treinamento via gradiente descendente

# %% [markdown]
# Função de perda:
# $$ J(\hat{y_i},y_i) = \frac{1}{M} \sum_{i=0}^{M-1} (\hat{y_i} - y_i)^2 $$

# %% [markdown]
# Gradiente:
# $$  \mathbf{\nabla{J_w}} = \frac{2}{M}\mathbf{x^T}(\mathbf{x w^T} - \mathbf{y}) $$

# %% [markdown]
# Atualização dos parâmetros pelo gradiente descendente:
# $$ \mathbf{w} = \mathbf{w} − \eta (\mathbf{\nabla J_w})^T $$

# %% [markdown]
# ### Laço de treinamento

# %%
num_epochs = 100
learning_rate = 0.5

# ATIVIDADE 1
# Lista para guardar a perda no final de cada época
loss_history = []

for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()

    # ATIVIDADE 1
    # Guarda o valor da perda
    loss_history.append(loss)

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss))
# Out:
# Epoch [1/100], Loss: 0.4692
# Epoch [2/100], Loss: 0.0581
# Epoch [3/100], Loss: 0.0305
# Epoch [4/100], Loss: 0.0281
# Epoch [5/100], Loss: 0.0274
# Epoch [6/100], Loss: 0.0268
# Epoch [7/100], Loss: 0.0263
# Epoch [8/100], Loss: 0.0258
# Epoch [9/100], Loss: 0.0254
# Epoch [10/100], Loss: 0.0250
# Epoch [11/100], Loss: 0.0246
# Epoch [12/100], Loss: 0.0243
# Epoch [13/100], Loss: 0.0240
# Epoch [14/100], Loss: 0.0238
# Epoch [15/100], Loss: 0.0235
# Epoch [16/100], Loss: 0.0233
# Epoch [17/100], Loss: 0.0231
# Epoch [18/100], Loss: 0.0229
# Epoch [19/100], Loss: 0.0228
# Epoch [20/100], Loss: 0.0226
# Epoch [21/100], Loss: 0.0225
# Epoch [22/100], Loss: 0.0224
# Epoch [23/100], Loss: 0.0223
# Epoch [24/100], Loss: 0.0222
# Epoch [25/100], Loss: 0.0221
# Epoch [26/100], Loss: 0.0220
# Epoch [27/100], Loss: 0.0219
# Epoch [28/100], Loss: 0.0218
# Epoch [29/100], Loss: 0.0218
# Epoch [30/100], Loss: 0.0217
# Epoch [31/100], Loss: 0.0217
# Epoch [32/100], Loss: 0.0216
# ...

# %%
# ATIVIDADE 1
# Plot da perda em função da época

plt.figure(figsize=(8,5))
plt.plot(loss_history)
plt.xlabel('Época')
plt.ylabel('Perda (MSE)')
plt.title('Perda por época')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Predict

# %%
y_pred = model.forward(x_train_bias)
plt.plot(x_train, y_train, 'ro', label='Original data')
plt.plot(x_train, y_pred, 'kx-', label='Fitting Line')

# %% [markdown]
# ### Parâmetros treinados

# %%
print(model.w)
# Out:
# [[0.26295353 0.68335641]]

# %% [markdown]
# ### Avaliação do modelo

# %%
loss = np.square(y_pred - y_train).mean()
loss
# Out:
# 0.02117000379151052

# %% [markdown]
# ### Valor ótimo, solução analítica

# %% [markdown]
# $$  \mathbf{w} =(\mathbf{x^T} \mathbf{x})^{−1}\mathbf{x^T} \mathbf{y} $$

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print(w_opt.T)
# Out:
# [[0.26134159 0.68646976]]

# %%
# ATIVIDADE 3
# Utilizando a solução ótima analítica

model.w = w_opt.T

y_pred_analitico = model.forward(x_train_bias)

mse_analitico = np.square(y_pred_analitico - y_train).mean()

print('MSE usando solução analítica:', mse_analitico)

# comparação com gradiente descendente
mse_gradiente = np.square(y_pred - y_train).mean()

print('MSE usando gradiente descendente:', mse_gradiente)
# Out:
# MSE usando solução analítica: 0.021169424119097165
# MSE usando gradiente descendente: 0.02117000379151052

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Questões

# %% [markdown]
# 1. Quantos parâmetros são treinados nesse modelo?
#
# 2. Qual é o número de atributos de entrada para a rede?
#
# 3. Qual é o número de saídas da rede?
#
# 4. Suponha que eu tenha agora 5 mil amostras para fazer a predição. Qual é o shape da matriz de entrada?
#    Qual é o shape do matriz de saída?

# %% [markdown]
# ## Respostas das Questões
#
# 1. São treinados 2 parâmetros: o bias e o peso da entrada.
#
# 2. O número de atributos de entrada é 1.
#
# 3. O número de saídas da rede é 1.
#
# 4. Para 5 mil amostras:
# - shape da entrada: (5000, 2)
# - shape da saída: (5000, 1)

# %% [markdown]
# ## Atividades

# %% [markdown]
# 1. Modifique o laço do treinamento via gradiente descendente para guardar em uma lista, o valor da perda no final
#    de cada época. Após o treinamento, plote o valor da perda em função da época.
# 2. Calcule o valor da perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.
# 3. Coloque os valores dos pesos da solução ótima analítica no modelo da rede e calcule o valor da perda (MSE) e
#    compare com o valor da perda obtida pelo método da otimização via gradiente descendente.

# %% [markdown]
# # Aprendizados

# %% [markdown]
# Durante essa atividade eu consegui entender melhor como funciona a regressão linear usando NumPy e gradiente descendente. Foi interessante acompanhar a diminuição da perda ao longo das épocas e perceber como os pesos vão sendo ajustados para melhorar as previsões. Também consegui entender melhor a diferença entre encontrar os pesos pelo gradiente descendente e pela solução analítica, vendo que os dois chegam em resultados muito parecidos.
